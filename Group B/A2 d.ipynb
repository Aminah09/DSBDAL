# %% [markdown]
# # Assignment 4
# Name: Amina Shaikh <br>
# Roll No. 3369
#
# ### 4. Visualize the data using Python libraries matplotlib,seaborn by plotting the graphs for assignment no. 2 and 3 ( Group B)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("heart.csv")
df1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
plt.hist(df1['age'])
plt.xlabel('age')
plt.plot()
# Out:
# []

# %%
x=df1.sex
y=df1.ca

plt.xlabel("sex")
plt.ylabel("ca")
plt.bar(x, y)
# Out:
# <BarContainer object of 303 artists>

# %%
sns.histplot(df1['chol'])
# Out:
# <AxesSubplot:xlabel='chol', ylabel='Count'>

# %%
sns.barplot(y='chol', x="cp", data=df1)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='chol'>

# %%
sns.lineplot(x="age", y="chol", data=df1)
plt.show()

# %%
sns.scatterplot(x="trestbps", y="thalach", data=df1)
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='thalach'>

# %%
sns.boxplot(y='chol', x="thal", data=df1)
# Out:
# <AxesSubplot:xlabel='thal', ylabel='chol'>

# %%
target = df1['cp']

# %%
cp_counts = df1['cp'].value_counts()

plt.pie(cp_counts, labels=cp_counts.index, autopct='%1.1f%%')
plt.title('Distribution of cp Variable')
plt.axis('equal')
plt.show()

# %%
age_values = df1['age']

plt.fill_between(range(len(age_values)), age_values)
plt.title('Area Plot for Age')
plt.xlabel('Data Points')
plt.ylabel('Age')
plt.show()

# %%
df2 = pd.read_csv("AirQuality.csv")
